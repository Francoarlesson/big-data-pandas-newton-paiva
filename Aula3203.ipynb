# %%
import pandas as pd

# %%
df = pd.read_csv('clima.csv')

# %%
df['MinTemp'].isnull().sum()
# Out:
# np.int64(1485)

# %%
df['MinTemp'].isnull().any()
# Out:
# np.True_

# %%
df[df['MinTemp'].isnull() == False]
# Out:
#               Data Localizacao  MinTemp  MaxTemp  Chuva  Evaporacao  LuzSol  \
# 0       2008-12-01      Albury     13.4     22.9    0.6         NaN     NaN
# 1       2008-12-02      Albury      7.4     25.1    0.0         NaN     NaN
# 2       2008-12-03      Albury     12.9     25.7    0.0         NaN     NaN
# 3       2008-12-04      Albury      9.2     28.0    0.0         NaN     NaN
# 4       2008-12-05      Albury     17.5     32.3    1.0         NaN     NaN
# ...            ...         ...      ...      ...    ...         ...     ...
# 145455  2017-06-21       Uluru      2.8     23.4    0.0         NaN     NaN
# 145456  2017-06-22       Uluru      3.6     25.3    0.0         NaN     NaN
# 145457  2017-06-23       Uluru      5.4     26.9    0.0         NaN     NaN
# 145458  2017-06-24       Uluru      7.8     27.0    0.0         NaN     NaN
# 145459  2017-06-25       Uluru     14.9      NaN    0.0         NaN     NaN
#
# ...

# %%
dados_02 = df.dropna()

# %%
df['MinTemp'].isnull().sum()
# Out:
# np.int64(1485)

# %%
df['MinTemp'].fillna(df['MinTemp'].mean(), inplace=True)
# Out:
# C:\Users\marco\AppData\Local\Temp\ipykernel_11384\1056995281.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['MinTemp'].fillna(df['MinTemp'].mean(), inplace=True)
# 0         13.4
# 1          7.4
# 2         12.9
# 3          9.2
# 4         17.5
#           ...
# 145455     2.8
# 145456     3.6
# 145457     5.4
# ...
